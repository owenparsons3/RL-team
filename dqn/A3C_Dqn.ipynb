# %% [markdown]
# ## **Overview**
#
# This code is adapted from a YouTube Tutorial by brthor. (Source:https://youtu.be/q-IPTPS9hgs?si=qZvMP9lkqZYbyfvO retrieved in January 2023.)
#
# Human-level control through deep reinforcement learning (paper): A3C algorithm introduced by deepmind
#
# The A3C algorithm, is a deep reinforcement learning method that learns directly from high-dimensional sensory inputs, such as images in Atari games.
#
# It combines policy-based and value-based methods to improve sample efficiency and stability.
#
# A3C agents are saved using serialization libraries and can be visualized using TensorBoard to monitor training dynamics and algorithm convergence. Preprocessing steps are necessary for Atari games.

# %% [markdown]
# ## **Set up**

# %%
# !pip install "gym[atari, accept-rom-license]"
# Out:
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.0.8)
# Requirement already satisfied: ale-py~=0.7.5 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.7.5)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license,atari]) (0.4.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.7.5->gym[accept-rom-license,atari]) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.66.2)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2024.2.2)

# %% [markdown]
# # **Importing all the necessary Libraries:**

# %%
import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import threading
import os
import cv2
import multiprocessing

# %% [markdown]
# # **Hyperparameters**
# Learning Rate (LR): Learning rate for the optimizer
#
# Discount Factor (GAMMA): Discount factor for future rewards
#
# Number of Workers (NUM_WORKERS): Number of worker threads (parallel agents)
#
# Number of Steps (NUM_STEPS): Number of steps each worker takes before updating the network
#
# Maximum Gradient Norm (MAX_GRAD_NORM):Maximum gradient norm for gradient clipping
#
# (VALUE_LOSS_COEFF): Value function loss coefficient
#
# Entropy Coefficient (ENTROPY_COEFF): Entropy coefficient to encourage exploration
#
# Replay Buffer Size (BUFFER_SIZE): Size of the replay buffer

# %%
# Hyperparameters

learning_rate = 0.001
discount_factor = 0.99
entropy_beta = 0.01
state_size = (84, 84, 4)  # Assuming pre-processing to 84x84 and 4 stacked frames

memory_size = 10000  # Experience replay memory size
batch_size = 32  # Batch size for experience replay sampling
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Pre-processing Function:**

# %%
def preprocess(frame):
    frame_resized = cv2.resize(frame, (80, 80), interpolation=cv2.INTER_LINEAR)
    frame_gray = cv2.cvtColor(frame_resized, cv2.COLOR_RGB2GRAY)
    frame_normalized = frame_gray / 255.0
    return np.expand_dims(frame_normalized, axis=2)  # Add channel dimension

# %% [markdown]
# # **Defining Actor-Critic Network**

# %%
class ActorCriticModel(Model):
    def __init__(self, action_size):
        super(ActorCriticModel, self).__init__()
        self.dense1 = Dense(128, activation='relu')
        self.flatten = Flatten()
        self.policy_logits = Dense(action_size)
        self.values = Dense(1)

    def call(self, inputs):
        x = self.flatten(inputs)
        x = self.dense1(x)
        logits = self.policy_logits(x)
        values = self.values(x)
        return logits, values

# %% [markdown]
# # **Class defination and training phase of the agent**:
# This code generates a global model A3C DQN agent and uses several worker threads for asynchronous training. The creation, operation, and synchronization of worker threads are coordinated by the train function.

# %%
class A3CAgent:
    def __init__(self, env_name):
        self.env_name = env_name
        self.env = gym.make(env_name)
        self.state_size = (80, 80, 1)  # Processed frame dimensions
        self.action_size = self.env.action_space.n
        self.optimizer = Adam(lr=0.001)
        self.global_model = ActorCriticModel(self.action_size)
        self.global_model(tf.convert_to_tensor(np.random.random((1, *self.state_size)), dtype=tf.float32))

    def train(self, max_episodes=1000):
        workers = []

        for i in range(multiprocessing.cpu_count()):
            worker_name = f'worker{i}'
            workers.append(Worker(self.global_model, self.optimizer, self.env_name, worker_name, max_episodes, self.action_size, self.state_size))

        for worker in workers:
            worker.start()

        for worker in workers:
            worker.join()

# %% [markdown]
# # **Worker thread in A3C:**
# Worker threads act as independent agents, collecting experience and potentially contributing to model updates through gradients or experience sharing.

# %%
class Worker(threading.Thread):
    def __init__(self, global_model, optimizer, env_name, name, max_episodes, action_size, state_size):
        super(Worker, self).__init__()
        self.global_model = global_model
        self.optimizer = optimizer
        self.env = gym.make(env_name)
        self.local_model = ActorCriticModel(action_size)
        self.name = name
        self.max_episodes = max_episodes
        self.state_size = state_size
        self.action_size = action_size

    def run(self):
        total_step = 1
        for episode in range(self.max_episodes):
            current_state = self.env.reset()
            current_state = preprocess(current_state)
            done = False
            while not done:
                logits, _ = self.local_model(tf.convert_to_tensor(current_state[None, :], dtype=tf.float32))
                probs = tf.nn.softmax(logits)
                action = np.random.choice(self.action_size, p=probs.numpy()[0])
                new_state, reward, done, _ = self.env.step(action)
                new_state = preprocess(new_state)
                current_state = new_state
                total_step += 1
            print(f"{self.name} Finished Episode {episode}")

# %%
if __name__ == "__main__":
    agent = A3CAgent('Breakout-v0')
    agent.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment Breakout-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:227: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# worker1 Finished Episode 0
# worker0 Finished Episode 0
# worker1 Finished Episode 1
# worker1 Finished Episode 2
# worker0 Finished Episode 1
# worker1 Finished Episode 3
# worker0 Finished Episode 2
# worker1 Finished Episode 4
# worker0 Finished Episode 3
# worker1 Finished Episode 5
# worker0 Finished Episode 4
# worker1 Finished Episode 6
# worker0 Finished Episode 5
# worker1 Finished Episode 7
# worker0 Finished Episode 6
# worker1 Finished Episode 8
# worker1 Finished Episode 9
# worker0 Finished Episode 7
# worker1 Finished Episode 10
# worker0 Finished Episode 8
# worker1 Finished Episode 11
# worker1 Finished Episode 12
# worker0 Finished Episode 9
# worker1 Finished Episode 13
# worker0 Finished Episode 10
# worker1 Finished Episode 14
# worker0 Finished Episode 11
# worker1 Finished Episode 15
# worker1 Finished Episode 16
# worker0 Finished Episode 12
# worker0 Finished Episode 13
# worker1 Finished Episode 17
# worker0 Finished Episode 14
# worker1 Finished Episode 18
# worker1 Finished Episode 19
# worker0 Finished Episode 15
# worker1 Finished Episode 20
# worker0 Finished Episode 16
# worker1 Finished Episode 21
# worker0 Finished Episode 17
# worker1 Finished Episode 22
# worker1 Finished Episode 23
# worker0 Finished Episode 18
# worker1 Finished Episode 24
# worker0 Finished Episode 19
# worker1 Finished Episode 25
# worker0 Finished Episode 20
# worker1 Finished Episode 26
# worker1 Finished Episode 27
# worker0 Finished Episode 21
# worker1 Finished Episode 28
# worker0 Finished Episode 22
# worker1 Finished Episode 29
# worker0 Finished Episode 23
# worker1 Finished Episode 30
# worker0 Finished Episode 24
# worker1 Finished Episode 31
# worker0 Finished Episode 25
# worker1 Finished Episode 32
# worker1 Finished Episode 33
# worker0 Finished Episode 26
# worker1 Finished Episode 34
# worker0 Finished Episode 27
# worker1 Finished Episode 35
# worker1 Finished Episode 36
# worker0 Finished Episode 28
# worker1 Finished Episode 37
# worker0 Finished Episode 29
# worker1 Finished Episode 38
# worker1 Finished Episode 39
# worker0 Finished Episode 30
# worker1 Finished Episode 40
# worker0 Finished Episode 31
# worker1 Finished Episode 41
# worker1 Finished Episode 42
# worker0 Finished Episode 32
# worker1 Finished Episode 43
# worker0 Finished Episode 33
# worker1 Finished Episode 44
# worker0 Finished Episode 34
# worker1 Finished Episode 45
# worker1 Finished Episode 46
# worker0 Finished Episode 35
# worker1 Finished Episode 47
# worker0 Finished Episode 36
# worker1 Finished Episode 48
# worker0 Finished Episode 37
# worker1 Finished Episode 49
# worker0 Finished Episode 38
# worker1 Finished Episode 50
# worker1 Finished Episode 51
# worker0 Finished Episode 39
# worker0 Finished Episode 40
# worker1 Finished Episode 52
# worker0 Finished Episode 41
# worker1 Finished Episode 53
# worker0 Finished Episode 42
# worker1 Finished Episode 54
# worker0 Finished Episode 43
# worker1 Finished Episode 55
# worker0 Finished Episode 44
# worker1 Finished Episode 56
# worker1 Finished Episode 57
# worker0 Finished Episode 45
# worker1 Finished Episode 58
# worker0 Finished Episode 46
# worker1 Finished Episode 59
# worker1 Finished Episode 60
# worker0 Finished Episode 47
# worker1 Finished Episode 61
# worker0 Finished Episode 48
# worker1 Finished Episode 62
# worker0 Finished Episode 49
# worker0 Finished Episode 50
# worker1 Finished Episode 63
# worker0 Finished Episode 51
# worker1 Finished Episode 64
# worker0 Finished Episode 52
# worker1 Finished Episode 65
# worker0 Finished Episode 53
# worker1 Finished Episode 66
# worker0 Finished Episode 54
# worker1 Finished Episode 67
# worker0 Finished Episode 55
# worker1 Finished Episode 68
# worker1 Finished Episode 69
# worker0 Finished Episode 56
# worker1 Finished Episode 70
# worker0 Finished Episode 57
# worker1 Finished Episode 71
# worker0 Finished Episode 58
# worker1 Finished Episode 72
# worker0 Finished Episode 59
# worker0 Finished Episode 60
# worker1 Finished Episode 73
# worker0 Finished Episode 61
# worker0 Finished Episode 62
# worker1 Finished Episode 74
# worker0 Finished Episode 63
# worker0 Finished Episode 64
# worker1 Finished Episode 75
# worker0 Finished Episode 65
# worker1 Finished Episode 76
# worker0 Finished Episode 66
# worker1 Finished Episode 77
# worker0 Finished Episode 67
# worker1 Finished Episode 78
# worker1 Finished Episode 79
# worker0 Finished Episode 68
# worker1 Finished Episode 80
# worker1 Finished Episode 81
# worker0 Finished Episode 69
# worker1 Finished Episode 82
# worker0 Finished Episode 70
# worker0 Finished Episode 71
# worker1 Finished Episode 83
# worker0 Finished Episode 72
# worker1 Finished Episode 84
# worker1 Finished Episode 85
# worker0 Finished Episode 73
# worker1 Finished Episode 86
# worker0 Finished Episode 74
# worker1 Finished Episode 87
# worker1 Finished Episode 88
# worker0 Finished Episode 75
# worker1 Finished Episode 89
# worker0 Finished Episode 76
# worker1 Finished Episode 90
# worker0 Finished Episode 77
# worker1 Finished Episode 91
# worker0 Finished Episode 78
# worker1 Finished Episode 92
# worker1 Finished Episode 93
# worker0 Finished Episode 79
# worker0 Finished Episode 80
# worker1 Finished Episode 94
# worker1 Finished Episode 95
# worker0 Finished Episode 81
# worker1 Finished Episode 96
# worker0 Finished Episode 82
# worker1 Finished Episode 97
# worker0 Finished Episode 83
# worker1 Finished Episode 98
# worker1 Finished Episode 99
# worker0 Finished Episode 84
# worker1 Finished Episode 100
# worker0 Finished Episode 85
# worker1 Finished Episode 101
# worker1 Finished Episode 226
# worker0 Finished Episode 190
# worker1 Finished Episode 227
# worker1 Finished Episode 228
# worker0 Finished Episode 191
# worker1 Finished Episode 229
# worker0 Finished Episode 192
# worker1 Finished Episode 230
# worker0 Finished Episode 193
# worker0 Finished Episode 194
# worker1 Finished Episode 231
# worker1 Finished Episode 232
# worker0 Finished Episode 195
# worker0 Finished Episode 196
# worker1 Finished Episode 233
# worker0 Finished Episode 197
# worker1 Finished Episode 234
# worker0 Finished Episode 198
# worker1 Finished Episode 235
# worker1 Finished Episode 236
# worker0 Finished Episode 199
# worker1 Finished Episode 237
# worker0 Finished Episode 200
# worker1 Finished Episode 238
# worker0 Finished Episode 201
# worker1 Finished Episode 239
# worker0 Finished Episode 202
# worker1 Finished Episode 240
# worker1 Finished Episode 241
# worker0 Finished Episode 203
# worker1 Finished Episode 242
# worker0 Finished Episode 204
# worker1 Finished Episode 243
# worker0 Finished Episode 205
# worker1 Finished Episode 244
# worker1 Finished Episode 245
# worker0 Finished Episode 206
# worker1 Finished Episode 246
# worker0 Finished Episode 207
# worker1 Finished Episode 247
# worker0 Finished Episode 208
# worker1 Finished Episode 248
# worker0 Finished Episode 209
# worker0 Finished Episode 210
# worker1 Finished Episode 249
# worker1 Finished Episode 250
# worker0 Finished Episode 211
# worker1 Finished Episode 251
# worker1 Finished Episode 252
# worker0 Finished Episode 212
# worker1 Finished Episode 253
# worker0 Finished Episode 213
# worker0 Finished Episode 214
# worker1 Finished Episode 254
# worker1 Finished Episode 255
# worker0 Finished Episode 215
# worker1 Finished Episode 256
# worker0 Finished Episode 216
# worker1 Finished Episode 257
# worker1 Finished Episode 258
# worker0 Finished Episode 217
# worker1 Finished Episode 259
# worker0 Finished Episode 218
# worker1 Finished Episode 260
# worker0 Finished Episode 219
# worker0 Finished Episode 220
# worker1 Finished Episode 261
# worker0 Finished Episode 221
# worker1 Finished Episode 262
# worker0 Finished Episode 222
# worker1 Finished Episode 263
# worker0 Finished Episode 223
# worker1 Finished Episode 264
# worker0 Finished Episode 224
# worker1 Finished Episode 265
# worker0 Finished Episode 225
# worker1 Finished Episode 266
# worker1 Finished Episode 267
# worker0 Finished Episode 226
# worker1 Finished Episode 268
# worker0 Finished Episode 227
# worker1 Finished Episode 269
# worker1 Finished Episode 270
# worker0 Finished Episode 228
# worker1 Finished Episode 271
# worker0 Finished Episode 229
# worker1 Finished Episode 272
# worker0 Finished Episode 230
# worker1 Finished Episode 273
# worker0 Finished Episode 231
# worker1 Finished Episode 274
# worker0 Finished Episode 232
# worker1 Finished Episode 275
# worker0 Finished Episode 233
# worker0 Finished Episode 234
# worker1 Finished Episode 276
# worker1 Finished Episode 277
# worker0 Finished Episode 235
# worker1 Finished Episode 278
# worker0 Finished Episode 236
# worker1 Finished Episode 279
# worker0 Finished Episode 237
# worker1 Finished Episode 280
# worker1 Finished Episode 281
# worker1 Finished Episode 282
# worker0 Finished Episode 238
# worker0 Finished Episode 239
# worker1 Finished Episode 283
# worker0 Finished Episode 240
# worker1 Finished Episode 284
# worker0 Finished Episode 241
# worker1 Finished Episode 285
# worker0 Finished Episode 242
# worker1 Finished Episode 286
# worker0 Finished Episode 399
# worker1 Finished Episode 474
# worker0 Finished Episode 400
# worker0 Finished Episode 401
# worker1 Finished Episode 475
# worker0 Finished Episode 402
# worker1 Finished Episode 476
# worker1 Finished Episode 477
# worker0 Finished Episode 403
# worker1 Finished Episode 478
# worker0 Finished Episode 404
# worker1 Finished Episode 479
# worker0 Finished Episode 405
# worker1 Finished Episode 480
# worker0 Finished Episode 406
# worker1 Finished Episode 481
# worker0 Finished Episode 407
# worker1 Finished Episode 482
# worker1 Finished Episode 483
# worker0 Finished Episode 408
# worker1 Finished Episode 484
# worker0 Finished Episode 409
# worker1 Finished Episode 485
# worker0 Finished Episode 410
# worker1 Finished Episode 486
# worker1 Finished Episode 487
# worker0 Finished Episode 411
# worker1 Finished Episode 488
# worker0 Finished Episode 412
# worker0 Finished Episode 413
# worker1 Finished Episode 489
# worker0 Finished Episode 414
# worker1 Finished Episode 490
# worker0 Finished Episode 415
# worker1 Finished Episode 491
# worker0 Finished Episode 416
# worker1 Finished Episode 492
# worker0 Finished Episode 417
# worker1 Finished Episode 493
# worker0 Finished Episode 418
# worker1 Finished Episode 494
# worker1 Finished Episode 495
# worker0 Finished Episode 419
# worker1 Finished Episode 496
# worker0 Finished Episode 420
# worker1 Finished Episode 497
# worker0 Finished Episode 421
# worker1 Finished Episode 498
# worker0 Finished Episode 422
# worker1 Finished Episode 499
# worker0 Finished Episode 423
# worker1 Finished Episode 500
# worker0 Finished Episode 424
# worker1 Finished Episode 501
# worker1 Finished Episode 502
# worker0 Finished Episode 425
# worker1 Finished Episode 503
# worker0 Finished Episode 426
# worker1 Finished Episode 504
# worker1 Finished Episode 505
# worker0 Finished Episode 427
# worker1 Finished Episode 506
# worker0 Finished Episode 428
# worker1 Finished Episode 507
# worker0 Finished Episode 429
# worker1 Finished Episode 508
# worker1 Finished Episode 509
# worker0 Finished Episode 430
# worker0 Finished Episode 431
# worker1 Finished Episode 510
# worker0 Finished Episode 432
# worker1 Finished Episode 511
# worker1 Finished Episode 512
# worker0 Finished Episode 433
# worker1 Finished Episode 513
# worker0 Finished Episode 434
# worker1 Finished Episode 514
# worker1 Finished Episode 515
# worker0 Finished Episode 435
# worker1 Finished Episode 516
# worker0 Finished Episode 436
# worker1 Finished Episode 517
# worker1 Finished Episode 518
# worker0 Finished Episode 437
# worker1 Finished Episode 519
# worker0 Finished Episode 438
# worker1 Finished Episode 520
# worker0 Finished Episode 439
# worker1 Finished Episode 521
# worker0 Finished Episode 440
# worker1 Finished Episode 522
# worker0 Finished Episode 441
# worker1 Finished Episode 523
# worker0 Finished Episode 442
# worker1 Finished Episode 524
# worker0 Finished Episode 443
# worker1 Finished Episode 525
# worker1 Finished Episode 526
# worker0 Finished Episode 444
# worker1 Finished Episode 527
# worker0 Finished Episode 445
# worker1 Finished Episode 528
# worker0 Finished Episode 446
# worker1 Finished Episode 529
# worker0 Finished Episode 447
# worker0 Finished Episode 448
# worker1 Finished Episode 530
# worker1 Finished Episode 531
# worker0 Finished Episode 449
# worker0 Finished Episode 450
# worker1 Finished Episode 532
# worker0 Finished Episode 451
# worker1 Finished Episode 533
# worker0 Finished Episode 452
# worker1 Finished Episode 534
# worker1 Finished Episode 535
# worker0 Finished Episode 453
# worker1 Finished Episode 536
# worker1 Finished Episode 537
# worker0 Finished Episode 454
# worker1 Finished Episode 538
# worker0 Finished Episode 455
# worker1 Finished Episode 539
# worker0 Finished Episode 456
# worker1 Finished Episode 540
# worker1 Finished Episode 541
# worker0 Finished Episode 457
# worker0 Finished Episode 458
# worker1 Finished Episode 542
# worker0 Finished Episode 459
# worker1 Finished Episode 543
# worker0 Finished Episode 460
# worker1 Finished Episode 544
# worker1 Finished Episode 545
# worker0 Finished Episode 461
# worker1 Finished Episode 546
# worker0 Finished Episode 462
# worker1 Finished Episode 547
# worker0 Finished Episode 463
# worker1 Finished Episode 548
# worker1 Finished Episode 549
# worker1 Finished Episode 550
# worker0 Finished Episode 464
# worker1 Finished Episode 551
# worker0 Finished Episode 465
# worker1 Finished Episode 552
# worker0 Finished Episode 466
# worker1 Finished Episode 553
# worker1 Finished Episode 554
# worker0 Finished Episode 467
# worker1 Finished Episode 555
# worker0 Finished Episode 468
# worker1 Finished Episode 556
# worker0 Finished Episode 469
# worker1 Finished Episode 557
# worker1 Finished Episode 558
# worker0 Finished Episode 470
# worker1 Finished Episode 559
# worker0 Finished Episode 471
# worker1 Finished Episode 560
# worker0 Finished Episode 472
# worker1 Finished Episode 561
# worker1 Finished Episode 562
# worker0 Finished Episode 473
# worker0 Finished Episode 474
# worker1 Finished Episode 563
# worker0 Finished Episode 475
# worker1 Finished Episode 564
# worker1 Finished Episode 565
# worker0 Finished Episode 476
# worker1 Finished Episode 566
# worker0 Finished Episode 477
# worker1 Finished Episode 567
# worker0 Finished Episode 478
# worker1 Finished Episode 568
# worker0 Finished Episode 479
# worker1 Finished Episode 569
# worker0 Finished Episode 480
# worker1 Finished Episode 570
# worker0 Finished Episode 481
# worker1 Finished Episode 571
# worker1 Finished Episode 572
# worker0 Finished Episode 482
# worker1 Finished Episode 573
# worker0 Finished Episode 483
# worker1 Finished Episode 574
# worker0 Finished Episode 484
# worker1 Finished Episode 575
# worker0 Finished Episode 485
# worker1 Finished Episode 576
# worker0 Finished Episode 486
# worker1 Finished Episode 577
# worker0 Finished Episode 487
# worker1 Finished Episode 578
# worker0 Finished Episode 488
# worker1 Finished Episode 579
# worker0 Finished Episode 489
# worker1 Finished Episode 580
# worker0 Finished Episode 490
# worker1 Finished Episode 581
# worker1 Finished Episode 582
# worker0 Finished Episode 491
# worker1 Finished Episode 583
# worker1 Finished Episode 584
# worker0 Finished Episode 492
# worker1 Finished Episode 585
# worker0 Finished Episode 493
# worker1 Finished Episode 586
# worker0 Finished Episode 494
# worker1 Finished Episode 587
# worker0 Finished Episode 495
# worker1 Finished Episode 588
# worker1 Finished Episode 589
# worker0 Finished Episode 496
# worker1 Finished Episode 590
# worker1 Finished Episode 591
# worker0 Finished Episode 497
# worker1 Finished Episode 592
# worker0 Finished Episode 498
# worker1 Finished Episode 593
# worker0 Finished Episode 499
# worker1 Finished Episode 594
# worker0 Finished Episode 500
# worker1 Finished Episode 595
# worker0 Finished Episode 501
# worker1 Finished Episode 596
# worker0 Finished Episode 502
# worker1 Finished Episode 597
# worker1 Finished Episode 598
# worker0 Finished Episode 503
# worker1 Finished Episode 599
# worker0 Finished Episode 504
# worker1 Finished Episode 600
# worker1 Finished Episode 601
# worker0 Finished Episode 505
# worker1 Finished Episode 602
# worker0 Finished Episode 506
# worker1 Finished Episode 603
# worker1 Finished Episode 604
# worker0 Finished Episode 507
# worker1 Finished Episode 605
# worker0 Finished Episode 508
# worker1 Finished Episode 606
# worker1 Finished Episode 607
# worker0 Finished Episode 509
# worker1 Finished Episode 608
# worker0 Finished Episode 510
# worker1 Finished Episode 609
# worker1 Finished Episode 610
# worker0 Finished Episode 511
# worker1 Finished Episode 611
# worker0 Finished Episode 512
# worker1 Finished Episode 612
# worker1 Finished Episode 613
# worker0 Finished Episode 513
# worker1 Finished Episode 614
# worker0 Finished Episode 514
# worker1 Finished Episode 615
# worker0 Finished Episode 515
# worker1 Finished Episode 616
# worker0 Finished Episode 516
# worker1 Finished Episode 617
# worker0 Finished Episode 517
# worker1 Finished Episode 618
# worker0 Finished Episode 518
# worker1 Finished Episode 619
# worker0 Finished Episode 519
# worker1 Finished Episode 620
# worker0 Finished Episode 520
# worker1 Finished Episode 621
# worker0 Finished Episode 521
# worker1 Finished Episode 622
# worker1 Finished Episode 623
# worker0 Finished Episode 522
# worker1 Finished Episode 624
# worker0 Finished Episode 523
# worker1 Finished Episode 625
# worker0 Finished Episode 524
# worker1 Finished Episode 626
# worker0 Finished Episode 525
# worker1 Finished Episode 627
# worker0 Finished Episode 526
# worker1 Finished Episode 628
# worker1 Finished Episode 629
# worker0 Finished Episode 527
# worker1 Finished Episode 630
# worker0 Finished Episode 528
# worker1 Finished Episode 631
# worker1 Finished Episode 632
# worker0 Finished Episode 529
# worker1 Finished Episode 633
# worker0 Finished Episode 530
# worker1 Finished Episode 634
# worker0 Finished Episode 531
# worker1 Finished Episode 635
# worker1 Finished Episode 636
# worker0 Finished Episode 532
# worker1 Finished Episode 637
# worker1 Finished Episode 638
# worker0 Finished Episode 533
# worker1 Finished Episode 639
# worker0 Finished Episode 534
# worker1 Finished Episode 640
# worker0 Finished Episode 535
# worker1 Finished Episode 641
# worker0 Finished Episode 536
# worker1 Finished Episode 642
# worker0 Finished Episode 537
# worker1 Finished Episode 643
# worker1 Finished Episode 644
# worker0 Finished Episode 538
# worker1 Finished Episode 645
# worker0 Finished Episode 539
# worker1 Finished Episode 646
# worker0 Finished Episode 540
# worker1 Finished Episode 647
# worker1 Finished Episode 648
# worker0 Finished Episode 541
# worker1 Finished Episode 649
# worker0 Finished Episode 542
# worker1 Finished Episode 650
# worker0 Finished Episode 543
# worker1 Finished Episode 651
# worker1 Finished Episode 652
# worker0 Finished Episode 544
# worker1 Finished Episode 653
# worker1 Finished Episode 654
# worker0 Finished Episode 545
# worker1 Finished Episode 655
# worker0 Finished Episode 546
# worker1 Finished Episode 656
# worker1 Finished Episode 657
# worker0 Finished Episode 547
# worker1 Finished Episode 658
# worker0 Finished Episode 548
# worker1 Finished Episode 659
# worker0 Finished Episode 549
# worker1 Finished Episode 660
# worker0 Finished Episode 550
# worker1 Finished Episode 661
# worker0 Finished Episode 551
# worker1 Finished Episode 662
